# %% [markdown]
# # Assignment 1. 나의 코딩 환경 구축하기
#
# **기초생물통계 · Colab 통계 실험실**
# 예상시간: **20–25분** · 핵심 개념: **Colab 사본 저장, 셀 실행, 입력과 출력**
#
# 코드를 외우거나 처음부터 작성하는 과제가 아닙니다. 제공된 셀을 순서대로 실행하고,
# 🟨 표시가 있는 값만 바꾼 뒤 결과를 통계 문장으로 설명합니다.
#
# ## 오늘의 질문
#
# > 입력값을 바꾸면 출력 숫자와 그래프는 어떻게 달라질까요?
#
# ## 진행 순서
#
# 1. **예측**: 실행 전에 결과를 예상합니다.
# 2. **실행**: `▶` 버튼을 위에서 아래로 누릅니다.
# 3. **변경**: 🟨 표시가 있는 값만 바꿉니다.
# 4. **관찰**: 숫자와 그래프에서 달라진 점을 찾습니다.
# 5. **설명**: 빈칸을 채워 통계 문장을 완성합니다.
#
# > 제출 전 `런타임 → 세션 다시 시작 → 모두 실행`으로 오류가 없는지 확인하세요.

# %% [markdown]
# ## 1. 실행 전에 예상하기
#
# `my_number`를 10에서 20으로 바꾸면 무엇이 달라질까요?
#
# - [ ] A. 그래프는 달라지지 않는다.
# - [ ] B. 입력 막대만 높아진다.
# - [ ] C. 입력 막대와 두 배 막대가 모두 높아진다.

# %%
# ▶ 1번: Colab 실습 환경을 확인합니다. 이 셀은 수정하지 않습니다.
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("✅ 실습 환경 준비 완료")
print("Python:", sys.version.split()[0])
print("NumPy:", np.__version__)
print("pandas:", pd.__version__)
# Out:
# ✅ 실습 환경 준비 완료
# Python: 3.13.15
# NumPy: 2.1.3
# pandas: 2.2.3

# %% [markdown]
# ## 나의 정보
#
# - 학번: `26010087`
# - 이름: `장진하`
# - 실행 전 나의 예상: `C`

# %%
# ▶ 2번: 먼저 10으로 실행한 뒤, 🟨 숫자를 20으로 바꾸어 다시 실행하세요.
my_number = 20  #@param {type:"slider", min:1, max:20, step:1}  # 🟨 여기만 바꾸세요
double_number = my_number * 2

print(f"입력한 숫자: {my_number}")
print(f"입력한 숫자의 2배: {double_number}")
# Out:
# 입력한 숫자: 20
# 입력한 숫자의 2배: 40

# %%
# ▶ 3번: 입력과 출력을 막대 높이로 확인합니다. 이 셀은 수정하지 않습니다.
plt.figure(figsize=(6, 3.5))
plt.bar(
    ["Input", "Input × 2"],
    [my_number, double_number],
    color=["#4C78A8", "#F58518"],
)
plt.ylim(0, 45)
plt.ylabel("Value")
plt.title("Input and Output")
plt.grid(axis="y", alpha=0.25)
plt.show()

# %% [markdown]
# ## 2. 관찰 결과를 완성하기
#
# 입력값을 10에서 20으로 바꾸자 출력 숫자는 __20__에서 __40___로 바뀌었고,
# 두 번째 막대의 높이는 ____더 높아졌다_____________.
#
# 오늘 Colab을 사용하면서 알게 된 점은 ____처음에 뭐가 뭔지 몰라서 우왕자왕했지만 알고 나니 별게 아니었다___________.

# %%
# ▶ 제출 확인
if my_number == 20:
    print("✅ 최종값 20으로 실행되었습니다. 답안 작성 후 저장하세요.")
else:
    print("🟨 my_number를 20으로 바꾸고 2번과 3번 셀을 다시 실행하세요.")
# Out:
# ✅ 최종값 20으로 실행되었습니다. 답안 작성 후 저장하세요.

# %% [markdown]
# ## 제출 체크리스트
#
# - [ ] 지정된 최종값으로 필수 셀을 모두 실행했다.
# - [ ] 표 또는 그래프의 핵심 숫자를 답안에 기록했다.
# - [ ] 과제에서 요구한 관찰·결론과, 해당되는 경우 한계 문장을 완성했다.
# - [ ] 출력이 보이는 상태로 저장했다.
# - [ ] 파일명을 `학번_A1.ipynb`로 바꾸고 다운로드했다.
#
# ## AI·타인 도움 사용
#
# - [ ] 사용하지 않음
# - [ ] 사용함 — 도움받은 부분과 내가 확인한 방법: `처음에 링크에서 수정하려고 하니 미리보기만 나와서 도저히 모르겠어서 AI를 활용했다. `
